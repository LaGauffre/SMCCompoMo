# %% [markdown]
# # Study of the computing time

# %%
# %run preamble_notebooks.py
danish = pd.read_csv("../Data/Danish/danish.csv").x
computing_time_free = pd.read_csv("../Data/Danish/computing_time_free.csv", sep = ';' )
#computing_time_free = pd.read_csv("../Data/Danish/computing_time_free_linux.csv", sep = ',' )
computing_time_fixed = pd.read_csv("../Data/Danish/computing_time_fixed_linux.csv",  sep = ',')
computing_time_free["threshold_method"] = "free"
computing_time_fixed["threshold_method"] = "fixed"
sns.histplot(computing_time_free["computing_time"]-  computing_time_free_linux["computing_time"])
# Out:
# <AxesSubplot:xlabel='computing_time', ylabel='Count'>

# %%
computing_time_fixed
# Out:
#         body         tail  model_type  popSize  paralell  computing_time  \
# 0       Burr  Pareto-Tail    disjoint     5000     False      218.634660
# 1       Burr  Pareto-Tail      simple     5000     False      170.610398
# 2       Burr  Pareto-Tail  continuous     5000     False      178.180296
# 3       Burr     GPD-Tail    disjoint     5000     False      263.933602
# 4       Burr     GPD-Tail      simple     5000     False      223.199314
# ..       ...          ...         ...      ...       ...             ...
# 103  Weibull  Pareto-Tail      simple    20000      True      178.301661
# 104  Weibull  Pareto-Tail  continuous    20000      True      178.775729
# 105  Weibull     GPD-Tail    disjoint    20000      True      321.483821
# 106  Weibull     GPD-Tail      simple    20000      True      240.070357
# 107  Weibull     GPD-Tail  continuous    20000      True      257.286749
#
#     threshold_method
# 0              fixed
# 1              fixed
# 2              fixed
# 3              fixed
# 4              fixed
# ..               ...
# 103            fixed
# 104            fixed
# 105            fixed
# 106            fixed
# 107            fixed
#
# [108 rows x 7 columns]

# %%
model_types = ["disjoint", "simple", "continuous"]
for model_type in model_types:
    print(model_type)
    df = computing_time_fixed.loc[computing_time_fixed.model_type == model_type]
    print(df.pivot(index = ["body", "tail"], columns=["paralell", "popSize"
                                                     ],values="computing_time").to_latex(float_format="%.0f"))
# Out:
# disjoint
# \begin{tabular}{llrrrrrr}
# \toprule
#         & paralell & \multicolumn{3}{l}{False} & \multicolumn{3}{l}{True} \\
#         & popSize & 5000  & 10000 & 20000 & 5000  & 10000 & 20000 \\
# body & tail &       &       &       &       &       &       \\
# \midrule
# Burr & GPD-Tail &   264 &   638 &  1049 &   158 &   263 &   557 \\
#         & Pareto-Tail &   219 &   512 &   970 &   132 &   229 &   452 \\
# Exp & GPD-Tail &    33 &    75 &   108 &    27 &    41 &    73 \\
#         & Pareto-Tail &    23 &    45 &    77 &    22 &    33 &    57 \\
# Weibull & GPD-Tail &   157 &   337 &   632 &    97 &   161 &   321 \\
#         & Pareto-Tail &   135 &   301 &   468 &    71 &   128 &   248 \\
# \bottomrule
# \end{tabular}
#
# simple
# \begin{tabular}{llrrrrrr}
# \toprule
#         & paralell & \multicolumn{3}{l}{False} & \multicolumn{3}{l}{True} \\
#         & popSize & 5000  & 10000 & 20000 & 5000  & 10000 & 20000 \\
# body & tail &       &       &       &       &       &       \\
# \midrule
# Burr & GPD-Tail &   223 &   483 &   894 &   134 &   220 &   433 \\
#         & Pareto-Tail &   171 &   427 &   714 &   107 &   188 &   370 \\
# Exp & GPD-Tail &    23 &    49 &    74 &    21 &    32 &    53 \\
#         & Pareto-Tail &    19 &    33 &    62 &    18 &    27 &    45 \\
# Weibull & GPD-Tail &   120 &   230 &   459 &    70 &   121 &   240 \\
#         & Pareto-Tail &    92 &   194 &   326 &    63 &    92 &   178 \\
# \bottomrule
# \end{tabular}
#
# continuous
# \begin{tabular}{llrrrrrr}
# \toprule
#         & paralell & \multicolumn{3}{l}{False} & \multicolumn{3}{l}{True} \\
#         & popSize & 5000  & 10000 & 20000 & 5000  & 10000 & 20000 \\
# body & tail &       &       &       &       &       &       \\
# \midrule
# Burr & GPD-Tail &   253 &   468 &   966 &   128 &   220 &   433 \\
#         & Pareto-Tail &   178 &   418 &   712 &   106 &   186 &   373 \\
# Exp & GPD-Tail &    26 &    55 &    72 &    21 &    31 &    54 \\
#         & Pareto-Tail &    17 &    33 &    57 &    16 &    23 &    40 \\
# Weibull & GPD-Tail &   146 &   235 &   561 &    72 &   131 &   257 \\
#         & Pareto-Tail &    86 &   198 &   326 &    57 &    94 &   179 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_12925/565524930.py:5: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(df.pivot(index = ["body", "tail"], columns=["paralell", "popSize"
# /tmp/ipykernel_12925/565524930.py:5: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(df.pivot(index = ["body", "tail"], columns=["paralell", "popSize"
# /tmp/ipykernel_12925/565524930.py:5: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(df.pivot(index = ["body", "tail"], columns=["paralell", "popSize"

# %%
model_types = ["disjoint", "simple", "continuous"]
for model_type in model_types:
    print(model_type)
    df = computing_time_free.loc[computing_time_free.model_type == model_type]
    print(df.pivot(index = ["body", "tail"], columns=["paralell", "popSize"
                                                     ],values="computing_time").to_latex(float_format="%.0f"))
# Out:
# disjoint
# \begin{tabular}{llrrrrrr}
# \toprule
#         & paralell & \multicolumn{3}{l}{False} & \multicolumn{3}{l}{True} \\
#         & popSize & 5000  & 10000 & 20000 & 5000  & 10000 & 20000 \\
# body & tail &       &       &       &       &       &       \\
# \midrule
# Burr & GPD-Tail &   117 &   179 &   374 &    77 &   144 &   256 \\
#         & Pareto-Tail &   115 &   235 &   465 &    84 &   138 &   340 \\
# Exp & GPD-Tail &    42 &    74 &   150 &    41 &    69 &   120 \\
#         & Pareto-Tail &    34 &    55 &   114 &    38 &    59 &    96 \\
# Weibull & GPD-Tail &    67 &   138 &   268 &    60 &   103 &   190 \\
#         & Pareto-Tail &    70 &   136 &   286 &    63 &   128 &   205 \\
# \bottomrule
# \end{tabular}
#
# simple
# \begin{tabular}{llrrrrrr}
# \toprule
#         & paralell & \multicolumn{3}{l}{False} & \multicolumn{3}{l}{True} \\
#         & popSize & 5000  & 10000 & 20000 & 5000  & 10000 & 20000 \\
# body & tail &       &       &       &       &       &       \\
# \midrule
# Burr & GPD-Tail &    90 &   227 &   419 &    77 &   128 &   251 \\
#         & Pareto-Tail &    94 &   181 &   377 &    67 &   101 &   241 \\
# Exp & GPD-Tail &    33 &    59 &   117 &    39 &    62 &   102 \\
#         & Pareto-Tail &    27 &    45 &    90 &    34 &    47 &    78 \\
# Weibull & GPD-Tail &    60 &  1031 &   224 &    56 &    88 &   161 \\
#         & Pareto-Tail &    57 &   105 &   214 &    55 &    91 &   158 \\
# \bottomrule
# \end{tabular}
#
# continuous
# \begin{tabular}{llrrrrrr}
# \toprule
#         & paralell & \multicolumn{3}{l}{False} & \multicolumn{3}{l}{True} \\
#         & popSize & 5000  & 10000 & 20000 & 5000  & 10000 & 20000 \\
# body & tail &       &       &       &       &       &       \\
# \midrule
# Burr & GPD-Tail &   103 &   187 &   468 &    73 &   142 &   302 \\
#         & Pareto-Tail &    94 &   198 &   378 &    66 &  2845 &   263 \\
# Exp & GPD-Tail &    25 &    45 &    89 &    33 &    49 &    74 \\
#         & Pareto-Tail &    23 &    36 &    72 &    34 &    41 &    65 \\
# Weibull & GPD-Tail &    76 &   150 &   315 &    70 &   119 &   224 \\
#         & Pareto-Tail &    53 &   100 &   205 &    50 &    81 &   152 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_12925/3704851257.py:5: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(df.pivot(index = ["body", "tail"], columns=["paralell", "popSize"
# /tmp/ipykernel_12925/3704851257.py:5: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(df.pivot(index = ["body", "tail"], columns=["paralell", "popSize"
# /tmp/ipykernel_12925/3704851257.py:5: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(df.pivot(index = ["body", "tail"], columns=["paralell", "popSize"
