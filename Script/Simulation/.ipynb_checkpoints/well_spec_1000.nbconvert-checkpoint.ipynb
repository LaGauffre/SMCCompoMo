# %%
# %run preamble_scripts.py

# %% [markdown]
# # Simulation study: the well specified case 1000 observations

# %%
n_sim, nobs, expo = 100, 1000, 250
err_pnl, popSize_screening, popsize_capi = 3e5, 1000, 5000

# %%
# Setting the true model
f1, f2 = bs.loss_model("Gamma", ["r1", "m1"]), bs.loss_model("Lomax", ["α2", "σ2"])
f_true = bs.spliced_loss_model(f1, f2, "continuous")
parms_true = np.array([1/2, 1, 2.5, 3, 1.5])
f_true.set_ppf(), f_true.set_pdf(),f_true.set_cdf()

# We set the priority to the 90% quantile and the limit to the 0.99% quantile
P, L = f_true.ppf(parms_true, 0.9), f_true.ppf(parms_true, 0.99)
premiums = f_true.PP(parms_true), f_true.XOLP(parms_true, P, L)

PnLs = np.array(f_true.PnL(parms_true, P, L, expo, premiums, safety_loadings = [0.05, 0.05], 
                           n_sim = err_pnl))
true_VaRs = [f_true.ppf(parms_true, prob) for prob in [0.95, 0.99, 0.995]]
true_cap = np.quantile(PnLs, [0.005, 0.01, 0.05])
true_cap
# Out:
# array([-148.34744827, -110.80781084,  -47.10230908])

# %% [markdown]
# We are interested in the estimations of the extreme quantile of the claim size distribution (of order 0.95, 0.99, 0.995) and the quantile of the aggregate losses over one year with a XOL reinsurance agreement

# %%
Xs = [f_true.sample(parms_true, nobs) for k in range(n_sim)]
ρ, c, n_step_max, err, paralell, n_proc, verbose = 1/2, 0.99, 25, 1e-6, False, 4, False
dfs = []
for k in range(n_sim):
    print("Simulation #"+str(k))
    def fit_spliced_models(i):
        trace, log_marg, DIC, WAIC = bs.smc(Xs[k], fs[i], popSize_screening, prior_spliced_model[i], ρ, c,n_step_max, err, paralell, 4, verbose)
        Wass_dist = bs.compute_Wasserstein(Xs[k], fs[i], trace.mean().values, 1)
        return(np.array([k, f_names[i], nobs, trace["γ"].mean(), log_marg, Wass_dist]))
    # %time res = Parallel(n_jobs= 40)(delayed(fit_spliced_models)(i) for i in range(len(fs)))
    df = pd.DataFrame(res, columns = ["sim", "model_name", "nobs", "γ_map", "log_marg", "Wass_dist"])
    df[df.columns[2:]] = df[df.columns[2:]].astype(float)

    df["posterior_probability"] = np.exp(df["log_marg"] - np.max(df["log_marg"])) / np.sum(np.exp(df["log_marg"] - np.max(df["log_marg"]))) 
    dfs.append(df)
# Out:
# Simulation #0
# CPU times: user 1min 58s, sys: 899 ms, total: 1min 59s
# Wall time: 2min 22s
# Simulation #1
# CPU times: user 1min 59s, sys: 368 ms, total: 1min 59s
# Wall time: 2min 26s
# Simulation #2
# CPU times: user 2min, sys: 420 ms, total: 2min 1s
# Wall time: 2min 24s
# Simulation #3
# CPU times: user 1min 59s, sys: 232 ms, total: 1min 59s
# Wall time: 2min 23s
# Simulation #4
# CPU times: user 1min 58s, sys: 424 ms, total: 1min 59s
# Wall time: 2min 27s
# Simulation #5
# CPU times: user 1min 58s, sys: 444 ms, total: 1min 59s
# Wall time: 2min 23s
# Simulation #6
# CPU times: user 1min 58s, sys: 452 ms, total: 1min 59s
# Wall time: 2min 22s
# Simulation #7
#   File "/home/pgoffard/miniconda3/lib/python3.8/site-packages/bayes_splicing/smc.py", line 118, in smc
#     res_trial = np.array([move_particle_trial(particle)
#   File "/home/pgoffard/miniconda3/lib/python3.8/site-packages/bayes_splicing/smc.py", line 118, in <listcomp>
#     res_trial = np.array([move_particle_trial(particle)
#   File "/home/pgoffard/miniconda3/lib/python3.8/site-packages/bayes_splicing/smc.py", line 107, in move_particle_trial
#     trace, acceptance = Gibbs_move(1,
# ZeroDivisionError: division by zero
# """
#
# The above exception was the direct cause of the following exception:
#
# ZeroDivisionError                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/miniconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1052
#    1053             with self._backend.retrieval_context():
# -> 1054                 self.retrieve()
#    1055             # Make sure that we get a last message telling us we are done
#    1056             elapsed_time = time.time() - self._start_time
#
# ~/miniconda3/lib/python3.8/site-packages/joblib/parallel.py in retrieve(self)
#     931             try:
#     932                 if getattr(self._backend, 'supports_timeout', False):
# --> 933                     self._output.extend(job.get(timeout=self.timeout))
#     934                 else:
#     935                     self._output.extend(job.get())
#
# ~/miniconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# ~/miniconda3/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     430                 raise CancelledError()
#     431             elif self._state == FINISHED:
# --> 432                 return self.__get_result()
#     433
#     434             self._condition.wait(timeout)
#
# ~/miniconda3/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     386     def __get_result(self):
#     387         if self._exception:
# --> 388             raise self._exception
#     389         else:
#     390             return self._result
#
# ZeroDivisionError: division by zero
# Simulation #41
# CPU times: user 1min 57s, sys: 756 ms, total: 1min 58s
# Wall time: 2min 26s
# Simulation #42
# CPU times: user 1min 58s, sys: 296 ms, total: 1min 58s
# Wall time: 2min 22s
# Simulation #43
# CPU times: user 1min 58s, sys: 268 ms, total: 1min 58s
# Wall time: 2min 20s
# Simulation #44
# CPU times: user 1min 57s, sys: 232 ms, total: 1min 57s
# Wall time: 2min 21s
# Simulation #45
# CPU times: user 1min 57s, sys: 296 ms, total: 1min 57s
# Wall time: 2min 21s
# Simulation #46
# CPU times: user 1min 57s, sys: 228 ms, total: 1min 57s
# Wall time: 2min 19s
# Simulation #47
# CPU times: user 1min 56s, sys: 244 ms, total: 1min 57s
# Wall time: 2min 29s
# Simulation #48
# CPU times: user 1min 57s, sys: 188 ms, total: 1min 57s
# Wall time: 2min 21s
# Simulation #49
# CPU times: user 1min 57s, sys: 220 ms, total: 1min 57s
# Wall time: 2min 21s
# Simulation #50
# CPU times: user 1min 56s, sys: 180 ms, total: 1min 57s
# Wall time: 2min 19s
# Simulation #51
# CPU times: user 1min 57s, sys: 208 ms, total: 1min 57s
# Wall time: 2min 20s
# Simulation #52
# CPU times: user 1min 56s, sys: 208 ms, total: 1min 57s
# Wall time: 2min 19s
# Simulation #53
# CPU times: user 1min 57s, sys: 196 ms, total: 1min 57s
# Wall time: 2min 20s
# Simulation #54
# CPU times: user 1min 57s, sys: 264 ms, total: 1min 57s
# Wall time: 2min 20s
# Simulation #55
# CPU times: user 1min 57s, sys: 248 ms, total: 1min 57s
# Wall time: 2min 20s
# Simulation #56
# CPU times: user 1min 57s, sys: 1.05 s, total: 1min 58s
# Wall time: 2min 27s
# Simulation #57
# CPU times: user 1min 56s, sys: 232 ms, total: 1min 57s
# Wall time: 2min 19s
# Simulation #58
# CPU times: user 1min 57s, sys: 272 ms, total: 1min 58s
# Wall time: 2min 21s
# Simulation #59
# CPU times: user 1min 56s, sys: 312 ms, total: 1min 57s
# Wall time: 2min 20s
# Simulation #60
# CPU times: user 1min 57s, sys: 208 ms, total: 1min 57s
# Wall time: 2min 20s
# Simulation #61
# CPU times: user 1min 56s, sys: 200 ms, total: 1min 57s
# Wall time: 2min 20s
# Simulation #62
# CPU times: user 1min 57s, sys: 168 ms, total: 1min 57s
# Wall time: 2min 20s
# Simulation #63
# CPU times: user 1min 57s, sys: 168 ms, total: 1min 57s
# Wall time: 2min 20s
# Simulation #64
# CPU times: user 1min 56s, sys: 256 ms, total: 1min 57s
# Wall time: 2min 20s
# Simulation #65
# CPU times: user 1min 57s, sys: 200 ms, total: 1min 57s
# Wall time: 2min 19s
# Simulation #66
# CPU times: user 1min 57s, sys: 251 ms, total: 1min 58s
# Wall time: 2min 21s
# Simulation #67
# CPU times: user 1min 56s, sys: 324 ms, total: 1min 57s
# Wall time: 2min 20s
# Simulation #68
# CPU times: user 1min 58s, sys: 248 ms, total: 1min 58s
# Wall time: 2min 23s
# Simulation #69
# CPU times: user 1min 57s, sys: 252 ms, total: 1min 57s
# Wall time: 2min 20s
# Simulation #70
# CPU times: user 1min 57s, sys: 256 ms, total: 1min 58s
# Wall time: 2min 25s
# Simulation #71
# CPU times: user 1min 58s, sys: 768 ms, total: 1min 59s
# Wall time: 2min 29s
# Simulation #72
# CPU times: user 1min 58s, sys: 656 ms, total: 1min 59s
# Wall time: 2min 25s
# Simulation #73
# CPU times: user 1min 57s, sys: 224 ms, total: 1min 57s
# Wall time: 2min 22s
# Simulation #74
# CPU times: user 1min 56s, sys: 228 ms, total: 1min 56s
# Wall time: 2min 20s
# Simulation #75
# CPU times: user 1min 56s, sys: 232 ms, total: 1min 56s
# Wall time: 2min 18s
# Simulation #76
# CPU times: user 1min 56s, sys: 196 ms, total: 1min 57s
# Wall time: 2min 21s
# Simulation #77
# CPU times: user 1min 56s, sys: 232 ms, total: 1min 56s
# Wall time: 2min 19s
# Simulation #78
# CPU times: user 1min 56s, sys: 236 ms, total: 1min 56s
# Wall time: 2min 19s
# Simulation #79
# CPU times: user 1min 56s, sys: 184 ms, total: 1min 56s
# Wall time: 2min 19s
# Simulation #80
# CPU times: user 1min 56s, sys: 164 ms, total: 1min 56s
# Wall time: 2min 18s
# Simulation #81
# CPU times: user 1min 56s, sys: 228 ms, total: 1min 56s
# Wall time: 2min 22s
# Simulation #82
# CPU times: user 1min 56s, sys: 180 ms, total: 1min 56s
# Wall time: 2min 19s
# Simulation #83
# CPU times: user 1min 56s, sys: 196 ms, total: 1min 56s
# Wall time: 2min 19s
# Simulation #84
# CPU times: user 1min 57s, sys: 224 ms, total: 1min 57s
# Wall time: 2min 19s
# Simulation #85
# CPU times: user 1min 57s, sys: 236 ms, total: 1min 57s
# Wall time: 2min 20s
# Simulation #86
# CPU times: user 1min 57s, sys: 556 ms, total: 1min 57s
# Wall time: 2min 22s
# Simulation #87
# CPU times: user 1min 56s, sys: 604 ms, total: 1min 57s
# Wall time: 2min 34s
# Simulation #88
# CPU times: user 1min 56s, sys: 324 ms, total: 1min 57s
# Wall time: 2min 19s
# Simulation #89
# CPU times: user 1min 56s, sys: 180 ms, total: 1min 57s
# Wall time: 2min 21s
# Simulation #90
# CPU times: user 1min 57s, sys: 228 ms, total: 1min 57s
# Wall time: 2min 22s
# Simulation #91
# CPU times: user 1min 56s, sys: 232 ms, total: 1min 56s
# Wall time: 2min 19s
# Simulation #92
# CPU times: user 1min 56s, sys: 208 ms, total: 1min 56s
# Wall time: 2min 18s
# Simulation #93
# CPU times: user 1min 56s, sys: 196 ms, total: 1min 56s
# Wall time: 2min 20s
# Simulation #94
# CPU times: user 1min 56s, sys: 224 ms, total: 1min 56s
# Wall time: 2min 19s
# Simulation #95
# CPU times: user 1min 56s, sys: 180 ms, total: 1min 56s
# Wall time: 2min 25s
# Simulation #96
# CPU times: user 1min 56s, sys: 176 ms, total: 1min 56s
# Wall time: 2min 19s
# Simulation #97
# CPU times: user 1min 56s, sys: 196 ms, total: 1min 56s
# Wall time: 2min 19s
# Simulation #98
# CPU times: user 1min 56s, sys: 192 ms, total: 1min 57s
# Wall time: 2min 20s
# Simulation #99
# CPU times: user 1min 56s, sys: 236 ms, total: 1min 56s
# Wall time: 2min 23s

# %%
pd.concat(dfs).to_csv("../../Data/Simulations/simu_postp_wellspec_"+str(nobs)+".csv", sep=',')

# %%
def compute_cap(k):
    df = dfs[k]
    s = (df["sim"] == str(k)).values & (df["nobs"] == nobs).values
    sorted_df = df[s].sort_values("posterior_probability", ascending = False)
    if method  == "true":
        selected_models = sorted_df[sorted_df.model_name == "Gamma_Lomax_continuous"]
    elif method  == "best":
        selected_models = sorted_df[:1]
    elif method  == "BMA":
        selected_models = sorted_df[:5]
    model_names_s = selected_models.model_name
    model_names_s

    traces, log_margs = [], []
    for model_name in model_names_s.values:
        f, prior, X = f_spliced_dic[model_name], prior_dic[model_name], Xs[k]
        trace, log_marg, DIC, WAIC = bs.smc(X, f, popsize_capi, prior, verbose = False)
        traces.append(trace), log_margs.append(log_marg)
    trace_dic = dict(zip(model_names_s.values, traces))
    model_weights_s = np.exp(log_margs - np.max(log_margs)) / np.sum(np.exp(log_margs - np.max(log_margs)))
    PNLS_post = []
    for i in range(int(err_pnl)):
        model_name = model_names_s.sample(1, weights = model_weights_s, replace = True).iloc[0]
        f = f_spliced_dic[model_name]
        PNLS_post.append( f.PnL(trace_dic[model_name].sample().values[0], P, L, 
                                expo, premiums, n_sim = 1)[0])
    return([k, method, nobs] + np.quantile(PNLS_post, [0.005, 0.01, 0.05]).tolist())

# %%
methods = ["true", "best", "BMA"]
dfs_cap = []
for method in methods: 
    print(method)
    # %time res = Parallel(n_jobs= 40)(delayed(compute_cap)(i) for i in range(n_sim))
    df_cap = pd.DataFrame(res, columns = ["sim", "method", "nobs", "cap005", "cap01", "cap05"])
    dfs_cap.append(df_cap)
# Out:
# true
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/pgoffard/miniconda3/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 431, in _process_worker
#     r = call_item()
#   File "/home/pgoffard/miniconda3/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 285, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/home/pgoffard/miniconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 595, in __call__
#     return self.func(*args, **kwargs)
#   File "/home/pgoffard/miniconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/home/pgoffard/miniconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "<ipython-input-1-e43712598b53>", line 20, in compute_cap
#   File "<__array_function__ internals>", line 5, in amax
#   File "/home/pgoffard/miniconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 2705, in amax
#     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#   File "/home/pgoffard/miniconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 87, in _wrapreduction
#     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ValueError: zero-size array to reduction operation maximum which has no identity
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/miniconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1052
#    1053             with self._backend.retrieval_context():
# -> 1054                 self.retrieve()
#    1055             # Make sure that we get a last message telling us we are done
#    1056             elapsed_time = time.time() - self._start_time
#
# ~/miniconda3/lib/python3.8/site-packages/joblib/parallel.py in retrieve(self)
#     931             try:
#     932                 if getattr(self._backend, 'supports_timeout', False):
# --> 933                     self._output.extend(job.get(timeout=self.timeout))
#     934                 else:
#     935                     self._output.extend(job.get())
#
# ~/miniconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# ~/miniconda3/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     430                 raise CancelledError()
#     431             elif self._state == FINISHED:
# --> 432                 return self.__get_result()
#     433
#     434             self._condition.wait(timeout)
#
# ~/miniconda3/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     386     def __get_result(self):
#     387         if self._exception:
# --> 388             raise self._exception
#     389         else:
#     390             return self._result
#
# ValueError: zero-size array to reduction operation maximum which has no identity
# best
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/pgoffard/miniconda3/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 431, in _process_worker
#     r = call_item()
#   File "/home/pgoffard/miniconda3/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 285, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/home/pgoffard/miniconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 595, in __call__
#     return self.func(*args, **kwargs)
#   File "/home/pgoffard/miniconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/home/pgoffard/miniconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "<ipython-input-1-e43712598b53>", line 20, in compute_cap
#   File "<__array_function__ internals>", line 5, in amax
#   File "/home/pgoffard/miniconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 2705, in amax
#     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#   File "/home/pgoffard/miniconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 87, in _wrapreduction
#     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ValueError: zero-size array to reduction operation maximum which has no identity
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/miniconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1052
#    1053             with self._backend.retrieval_context():
# -> 1054                 self.retrieve()
#    1055             # Make sure that we get a last message telling us we are done
#    1056             elapsed_time = time.time() - self._start_time
#
# ~/miniconda3/lib/python3.8/site-packages/joblib/parallel.py in retrieve(self)
#     931             try:
#     932                 if getattr(self._backend, 'supports_timeout', False):
# --> 933                     self._output.extend(job.get(timeout=self.timeout))
#     934                 else:
#     935                     self._output.extend(job.get())
#
# ~/miniconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# ~/miniconda3/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     430                 raise CancelledError()
#     431             elif self._state == FINISHED:
# --> 432                 return self.__get_result()
#     433
#     434             self._condition.wait(timeout)
#
# ~/miniconda3/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     386     def __get_result(self):
#     387         if self._exception:
# --> 388             raise self._exception
#     389         else:
#     390             return self._result
#
# ValueError: zero-size array to reduction operation maximum which has no identity
# BMA
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/pgoffard/miniconda3/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 431, in _process_worker
#     r = call_item()
#   File "/home/pgoffard/miniconda3/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 285, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/home/pgoffard/miniconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 595, in __call__
#     return self.func(*args, **kwargs)
#   File "/home/pgoffard/miniconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/home/pgoffard/miniconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "<ipython-input-1-e43712598b53>", line 20, in compute_cap
#   File "<__array_function__ internals>", line 5, in amax
#   File "/home/pgoffard/miniconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 2705, in amax
#     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#   File "/home/pgoffard/miniconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 87, in _wrapreduction
#     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ValueError: zero-size array to reduction operation maximum which has no identity
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/miniconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1052
#    1053             with self._backend.retrieval_context():
# -> 1054                 self.retrieve()
#    1055             # Make sure that we get a last message telling us we are done
#    1056             elapsed_time = time.time() - self._start_time
#
# ~/miniconda3/lib/python3.8/site-packages/joblib/parallel.py in retrieve(self)
#     931             try:
#     932                 if getattr(self._backend, 'supports_timeout', False):
# --> 933                     self._output.extend(job.get(timeout=self.timeout))
#     934                 else:
#     935                     self._output.extend(job.get())
#
# ~/miniconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# ~/miniconda3/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     430                 raise CancelledError()
#     431             elif self._state == FINISHED:
# --> 432                 return self.__get_result()
#     433
#     434             self._condition.wait(timeout)
#
# ~/miniconda3/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     386     def __get_result(self):
#     387         if self._exception:
# --> 388             raise self._exception
#     389         else:
#     390             return self._result
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
pd.concat(dfs_cap).join(pd.DataFrame(
    [true_cap for k in range(n_sim * len(methods))], 
    columns = ["cap005_true", "cap01_true", "cap05_true"])).to_csv(
    "../../Data/Simulations/simu_capi_wellspec_"+str(nobs)+".csv", sep=',')

# %%
pd.concat(dfs_cap).join(pd.DataFrame(
    [true_cap for k in range(n_sim * len(methods))], 
    columns = ["cap005_true", "cap01_true", "cap05_true"]))
# Out:
#     sim                    method  nobs                 cap005  \
# 0    99    Exp_Weibull_continuous  1000  0.0025550134878616487
# 0    99    Exp_Weibull_continuous  1000  0.0025550134878616487
# 0    99    Exp_Weibull_continuous  1000  0.0025550134878616487
# 1    99  Exp_Lognormal_continuous  1000    0.09950874490769157
# 1    99  Exp_Lognormal_continuous  1000    0.09950874490769157
# ..   ..                       ...   ...                    ...
# 108  99       Burr_Exp_continuous  1000      7.594881789160213
# 108  99       Burr_Exp_continuous  1000      7.594881789160213
# 109  99     Burr_Gamma_continuous  1000       5.12510296390551
# 109  99     Burr_Gamma_continuous  1000       5.12510296390551
# 109  99     Burr_Gamma_continuous  1000       5.12510296390551
#
#                   cap01               cap05  cap005_true  cap01_true  \
# 0    -599.9638150304517  145.58346283978602  -148.347448 -110.807811
# 0    -599.9638150304517  145.58346283978602  -148.347448 -110.807811
# 0    -599.9638150304517  145.58346283978602  -148.347448 -110.807811
# 1    -616.3320323914725  59.438257367204855  -148.347448 -110.807811
# 1    -616.3320323914725  59.438257367204855  -148.347448 -110.807811
# ..                  ...                 ...          ...         ...
# 108  -601.7470111319724  114.70878466885522  -148.347448 -110.807811
# 108  -601.7470111319724  114.70878466885522  -148.347448 -110.807811
# 109  -601.2622189477178  120.09359813251179  -148.347448 -110.807811
# 109  -601.2622189477178  120.09359813251179  -148.347448 -110.807811
# 109  -601.2622189477178  120.09359813251179  -148.347448 -110.807811
#
#      cap05_true
# 0    -47.102309
# 0    -47.102309
# 0    -47.102309
# 1    -47.102309
# 1    -47.102309
# ..          ...
# 108  -47.102309
# 108  -47.102309
# 109  -47.102309
# 109  -47.102309
# 109  -47.102309
#
# [330 rows x 9 columns]
